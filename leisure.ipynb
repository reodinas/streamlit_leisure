# %%
import pandas as pd

# %%
week1 = pd.read_csv('data/CI_DAY_AVRG_LSR_CLTUR_TIME_ND_USE_RLIMP_INFO_20221005.csv')
week2 = pd.read_csv('data/CI_DAY_AVRG_LSR_CLTUR_TIME_ND_USE_RLIMP_INFO_20221012.csv')
week3 = pd.read_csv('data/CI_DAY_AVRG_LSR_CLTUR_TIME_ND_USE_RLIMP_INFO_20221019.csv')
week4 = pd.read_csv('data/CI_DAY_AVRG_LSR_CLTUR_TIME_ND_USE_RLIMP_INFO_20221026.csv')

# %%
week1
# Out:
#      RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0      53322175         20221005               F           20대
# 1      53322586         20221005               F           50대
# 2      53322613         20221005               F           50대
# 3      53322634         20221005               F           60대
# 4      53322657         20221005               M           60대
# ..          ...              ...             ...           ...
# 525    53376787         20221005               F           30대
# 526    53377297         20221005               F           40대
# 527    53377355         20221005               M           30대
# 528    53377490         20221005               M           30대
# 529    53377524         20221005               F           60대
#
#     ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  WORKDAY_DAY_AVRG_LSR_TIME_VALUE  \
# 0               서울특별시         300이상500만원 미만                                5
# 1               서울특별시         300이상500만원 미만                                3
# 2               서울특별시              700만원 이상                                3
# 3               서울특별시              300만원 미만                                2
# 4               서울특별시         300이상500만원 미만                               10
# ..                ...                   ...                              ...
# 525               경기도         500이상700만원 미만                                1
# 526             서울특별시         500이상700만원 미만                                2
# 527               경기도              300만원 미만                                1
# 528             대전광역시         300이상500만원 미만                                3
# 529               경기도         300이상500만원 미만                                3
#
#      WKEND_DAY_AVRG_LSR_TIME_VALUE  ONE_WEEK_TOT_LSR_TIME_VALUE  \
# 0                                8                           41
# 1                                2                           19
# 2                               12                           39
# 3                               10                           30
# 4                                4                           58
# ..                             ...                          ...
# 525                              6                           17
# 526                              5                           20
# 527                              1                            7
# 528                              3                           21
# 529                              3                           21
#
#      LSR_TIME_REST_RCRT_USE_RATE  LSR_TIME_HOBBY_USE_RATE  \
# 0                             20                       30
# 1                             60                       10
# 2                              0                       50
# 3                             50                       10
# 4                             10                       30
# ..                           ...                      ...
# 525                           40                       20
# 526                           50                        5
# 527                          100                        0
# 528                           50                       30
# 529                           10                       40
#
#      LSR_TIME_SELF_IMPT_USE_RATE  LSR_TIME_TWDPSN_RLTN_FLWSP_USE_RATE  \
# 0                             50                                    0
# 1                              5                                   15
# 2                              0                                   50
# 3                             10                                   10
# 4                             50                                   10
# ..                           ...                                  ...
# 525                           10                                   20
# 526                           10                                   35
# 527                            0                                    0
# 528                            0                                   20
# 529                           20                                   30
#
#      LSR_TIME_ETC_USE_RATE
# 0                        0
# 1                       10
# 2                        0
# 3                       20
# 4                        0
# ..                     ...
# 525                     10
# 526                      0
# 527                      0
# 528                      0
# 529                      0
#
# [530 rows x 14 columns]

# %%
week4.isna().sum()
# Out:
# RESPOND_ID                             0
# EXAMIN_BEGIN_DE                        0
# SEXDSTN_FLAG_CD                        0
# AGRDE_FLAG_NM                          0
# ANSWRR_OC_AREA_NM                      0
# HSHLD_INCOME_DGREE_NM                  0
# WORKDAY_DAY_AVRG_LSR_TIME_VALUE        0
# WKEND_DAY_AVRG_LSR_TIME_VALUE          0
# ONE_WEEK_TOT_LSR_TIME_VALUE            0
# LSR_TIME_REST_RCRT_USE_RATE            0
# LSR_TIME_HOBBY_USE_RATE                0
# LSR_TIME_SELF_IMPT_USE_RATE            0
# LSR_TIME_TWDPSN_RLTN_FLWSP_USE_RATE    0
# LSR_TIME_ETC_USE_RATE                  0
# dtype: int64

# %%
# na없음. 하지만 소득정도에 무응답이라고 적힌 사람들이 있다.

# %%
# 무응답 데이터 삭제는 머신러닝할때 하자

# %%
week1[week1['HSHLD_INCOME_DGREE_NM'] == '무응답']
# Out:
#      RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 7      53322749         20221005               F           20대
# 12     53323560         20221005               F           30대
# 14     53323687         20221005               F           30대
# 49     53328244         20221005               M           40대
# 59     53329170         20221005               M           20대
# 62     53329438         20221005               F           20대
# 70     53330089         20221005               M           20대
# 75     53330479         20221005               M           20대
# 88     53331373         20221005               F           40대
# 93     53332346         20221005               M           50대
# 118    53334920         20221005               M           20대
# 124    53335540         20221005               M           40대
# 127    53335771         20221005               F           50대
# 151    53337656         20221005               M           50대
# 174    53339085         20221005               F           20대
# 226    53344265         20221005               M           20대
# 244    53345992         20221005               F           20대
# 249    53346182         20221005               F           20대
# 251    53346349         20221005               M           20대
# 256    53346832         20221005               M           20대
# 265    53347622         20221005               M           20대
# 266    53348101         20221005               F           50대
# 267    53348143         20221005               M           20대
# 274    53348980         20221005               M           20대
# 295    53350746         20221005               M           20대
# 317    53352986         20221005               M           30대
# 338    53355579         20221005               F           20대
# 359    53358205         20221005               M           20대
# 366    53358642         20221005               M           40대
# 429    53364619         20221005               M           40대
# 450    53366917         20221005               M           60대
# 478    53371628         20221005               F           30대
# 499    53374427         20221005               F           20대
# 512    53375597         20221005               M           30대
# 518    53375960         20221005               F           20대
#
#     ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  WORKDAY_DAY_AVRG_LSR_TIME_VALUE  \
# 7               서울특별시                   무응답                                5
# 12                경기도                   무응답                                1
# 14              서울특별시                   무응답                                2
# 49                경기도                   무응답                                1
# 59               전라북도                   무응답                                2
# 62              대전광역시                   무응답                                2
# 70               충청북도                   무응답                               10
# 75              부산광역시                   무응답                                6
# 88              대구광역시                   무응답                                2
# 93                강원도                   무응답                                2
# 118             서울특별시                   무응답                                1
# 124               경기도                   무응답                                4
# 127             인천광역시                   무응답                                4
# 151             부산광역시                   무응답                                1
# 174               경기도                   무응답                                4
# 226             인천광역시                   무응답                                2
# 244               경기도                   무응답                                2
# 249             대구광역시                   무응답                                3
# 251               경기도                   무응답                                4
# 256              충청남도                   무응답                                2
# 265              전라북도                   무응답                                2
# 266             서울특별시                   무응답                               10
# 267               경기도                   무응답                                3
# 274             서울특별시                   무응답                                2
# 295             대구광역시                   무응답                                4
# 317             서울특별시                   무응답                                1
# 338              전라남도                   무응답                               12
# 359             광주광역시                   무응답                                5
# 366             인천광역시                   무응답                                1
# 429              전라북도                   무응답                                3
# 450             대구광역시                   무응답                               10
# 478             부산광역시                   무응답                                2
# 499               경기도                   무응답                                7
# 512              충청북도                   무응답                                4
# 518             대구광역시                   무응답                                0
#
#      WKEND_DAY_AVRG_LSR_TIME_VALUE  ONE_WEEK_TOT_LSR_TIME_VALUE  \
# 7                                8                           41
# 12                               7                           19
# 14                               2                           14
# 49                               3                           11
# 59                               5                           20
# 62                              10                           30
# 70                              10                           70
# 75                              10                           50
# 88                               3                           16
# 93                               6                           22
# 118                              3                           11
# 124                              8                           36
# 127                              8                           36
# 151                              1                            7
# 174                             12                           44
# 226                              2                           14
# 244                              4                           18
# 249                              8                           31
# 251                              8                           36
# 256                              8                           26
# 265                              4                           18
# 266                             10                           70
# 267                              8                           31
# 274                              4                           18
# 295                              4                           28
# 317                              1                            7
# 338                             12                           84
# 359                             10                           45
# 366                              5                           15
# 429                              7                           29
# 450                             10                           70
# 478                              3                           16
# 499                              7                           49
# 512                              7                           34
# 518                              2                            4
#
#      LSR_TIME_REST_RCRT_USE_RATE  LSR_TIME_HOBBY_USE_RATE  \
# 7                             70                        0
# 12                            90                        5
# 14                            80                        0
# 49                            70                        0
# 59                            80                        0
# 62                            80                        0
# 70                            40                       15
# 75                            80                        0
# 88                            40                       10
# 93                            70                        0
# 118                           10                       40
# 124                           50                       50
# 127                           40                        0
# 151                           90                        0
# 174                           50                       10
# 226                           50                       50
# 244                           70                        0
# 249                           75                        5
# 251                           80                        0
# 256                           65                       15
# 265                           20                       30
# 266                           80                        0
# 267                          100                        0
# 274                           50                       20
# 295                           20                       30
# 317                            5                        5
# 338                           90                       10
# 359                           30                       20
# 366                           80                        0
# 429                           30                       10
# 450                           80                        0
# 478                           40                       10
# 499                           80                        0
# 512                           50                       10
# 518                           50                        0
#
#      LSR_TIME_SELF_IMPT_USE_RATE  LSR_TIME_TWDPSN_RLTN_FLWSP_USE_RATE  \
# 7                              0                                   30
# 12                             0                                    5
# 14                            10                                   10
# 49                            30                                    0
# 59                             0                                   20
# 62                             0                                   20
# 70                            15                                   30
# 75                             0                                   20
# 88                             5                                   45
# 93                            10                                   20
# 118                           45                                    5
# 124                            0                                    0
# 127                           20                                   40
# 151                            0                                    0
# 174                           10                                   30
# 226                            0                                    0
# 244                           10                                   20
# 249                           10                                   10
# 251                            0                                   20
# 256                            5                                   15
# 265                            0                                   50
# 266                            0                                   20
# 267                            0                                    0
# 274                            0                                   30
# 295                           20                                   30
# 317                           90                                    0
# 338                            0                                    0
# 359                            0                                   50
# 366                            0                                   20
# 429                           30                                   30
# 450                           10                                   10
# 478                           30                                   20
# 499                           10                                   10
# 512                           15                                   25
# 518                            0                                   50
#
#      LSR_TIME_ETC_USE_RATE
# 7                        0
# 12                       0
# 14                       0
# 49                       0
# 59                       0
# 62                       0
# 70                       0
# 75                       0
# 88                       0
# 93                       0
# 118                      0
# 124                      0
# 127                      0
# 151                     10
# 174                      0
# 226                      0
# 244                      0
# 249                      0
# 251                      0
# 256                      0
# 265                      0
# 266                      0
# 267                      0
# 274                      0
# 295                      0
# 317                      0
# 338                      0
# 359                      0
# 366                      0
# 429                      0
# 450                      0
# 478                      0
# 499                      0
# 512                      0
# 518                      0

# %%
(week1['HSHLD_INCOME_DGREE_NM'] == '무응답').sum()
# Out:
# 35

# %%
# week1,2,3,4 병함

# %%
week1
# Out:
#      RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0      53322175         20221005               F           20대
# 1      53322586         20221005               F           50대
# 2      53322613         20221005               F           50대
# 3      53322634         20221005               F           60대
# 4      53322657         20221005               M           60대
# ..          ...              ...             ...           ...
# 525    53376787         20221005               F           30대
# 526    53377297         20221005               F           40대
# 527    53377355         20221005               M           30대
# 528    53377490         20221005               M           30대
# 529    53377524         20221005               F           60대
#
#     ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  WORKDAY_DAY_AVRG_LSR_TIME_VALUE  \
# 0               서울특별시         300이상500만원 미만                                5
# 1               서울특별시         300이상500만원 미만                                3
# 2               서울특별시              700만원 이상                                3
# 3               서울특별시              300만원 미만                                2
# 4               서울특별시         300이상500만원 미만                               10
# ..                ...                   ...                              ...
# 525               경기도         500이상700만원 미만                                1
# 526             서울특별시         500이상700만원 미만                                2
# 527               경기도              300만원 미만                                1
# 528             대전광역시         300이상500만원 미만                                3
# 529               경기도         300이상500만원 미만                                3
#
#      WKEND_DAY_AVRG_LSR_TIME_VALUE  ONE_WEEK_TOT_LSR_TIME_VALUE  \
# 0                                8                           41
# 1                                2                           19
# 2                               12                           39
# 3                               10                           30
# 4                                4                           58
# ..                             ...                          ...
# 525                              6                           17
# 526                              5                           20
# 527                              1                            7
# 528                              3                           21
# 529                              3                           21
#
#      LSR_TIME_REST_RCRT_USE_RATE  LSR_TIME_HOBBY_USE_RATE  \
# 0                             20                       30
# 1                             60                       10
# 2                              0                       50
# 3                             50                       10
# 4                             10                       30
# ..                           ...                      ...
# 525                           40                       20
# 526                           50                        5
# 527                          100                        0
# 528                           50                       30
# 529                           10                       40
#
#      LSR_TIME_SELF_IMPT_USE_RATE  LSR_TIME_TWDPSN_RLTN_FLWSP_USE_RATE  \
# 0                             50                                    0
# 1                              5                                   15
# 2                              0                                   50
# 3                             10                                   10
# 4                             50                                   10
# ..                           ...                                  ...
# 525                           10                                   20
# 526                           10                                   35
# 527                            0                                    0
# 528                            0                                   20
# 529                           20                                   30
#
#      LSR_TIME_ETC_USE_RATE
# 0                        0
# 1                       10
# 2                        0
# 3                       20
# 4                        0
# ..                     ...
# 525                     10
# 526                      0
# 527                      0
# 528                      0
# 529                      0
#
# [530 rows x 14 columns]

# %%
week2
# Out:
#      RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0      53322214         20221012               M           30대
# 1      53322376         20221012               M           60대
# 2      53323026         20221012               F           40대
# 3      53323101         20221012               F           40대
# 4      53323193         20221012               F           40대
# ..          ...              ...             ...           ...
# 528    53376613         20221012               F           60대
# 529    53376871         20221012               F           60대
# 530    53376895         20221012               F           50대
# 531    53377071         20221012               M           40대
# 532    53377181         20221012               F           60대
#
#     ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  WORKDAY_DAY_AVRG_LSR_TIME_VALUE  \
# 0               서울특별시         300이상500만원 미만                                2
# 1               서울특별시              300만원 미만                                2
# 2               서울특별시         300이상500만원 미만                                1
# 3               서울특별시         500이상700만원 미만                                5
# 4               서울특별시                   무응답                                3
# ..                ...                   ...                              ...
# 528             서울특별시         500이상700만원 미만                                1
# 529              충청남도         300이상500만원 미만                                4
# 530             광주광역시         500이상700만원 미만                                2
# 531             대구광역시              300만원 미만                                1
# 532              경상북도              700만원 이상                                6
#
#      WKEND_DAY_AVRG_LSR_TIME_VALUE  ONE_WEEK_TOT_LSR_TIME_VALUE  \
# 0                                5                           20
# 1                                5                           20
# 2                                2                            9
# 3                                7                           39
# 4                               10                           35
# ..                             ...                          ...
# 528                              2                            9
# 529                              5                           30
# 530                              1                           12
# 531                              5                           15
# 532                              4                           38
#
#      LSR_TIME_REST_RCRT_USE_RATE  LSR_TIME_HOBBY_USE_RATE  \
# 0                            100                        0
# 1                             40                       20
# 2                             50                       45
# 3                             40                        0
# 4                             10                       50
# ..                           ...                      ...
# 528                           20                       10
# 529                            0                       30
# 530                           20                       70
# 531                           40                       10
# 532                           40                       30
#
#      LSR_TIME_SELF_IMPT_USE_RATE  LSR_TIME_TWDPSN_RLTN_FLWSP_USE_RATE  \
# 0                              0                                    0
# 1                              0                                   20
# 2                              0                                    5
# 3                             20                                   40
# 4                             20                                   10
# ..                           ...                                  ...
# 528                           20                                   30
# 529                            0                                   50
# 530                           10                                    0
# 531                           50                                    0
# 532                           20                                   10
#
#      LSR_TIME_ETC_USE_RATE
# 0                        0
# 1                       20
# 2                        0
# 3                        0
# 4                       10
# ..                     ...
# 528                     20
# 529                     20
# 530                      0
# 531                      0
# 532                      0
#
# [533 rows x 14 columns]

# %%
week1.shape
# Out:
# (530, 14)

# %%
week2.shape
# Out:
# (533, 14)

# %%
week3.shape
# Out:
# (529, 14)

# %%
week4.shape
# Out:
# (530, 14)

# %%
week1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   RESPOND_ID                           530 non-null    int64
#  1   EXAMIN_BEGIN_DE                      530 non-null    int64
#  2   SEXDSTN_FLAG_CD                      530 non-null    object
#  3   AGRDE_FLAG_NM                        530 non-null    object
#  4   ANSWRR_OC_AREA_NM                    530 non-null    object
#  5   HSHLD_INCOME_DGREE_NM                530 non-null    object
#  6   WORKDAY_DAY_AVRG_LSR_TIME_VALUE      530 non-null    int64
#  7   WKEND_DAY_AVRG_LSR_TIME_VALUE        530 non-null    int64
#  8   ONE_WEEK_TOT_LSR_TIME_VALUE          530 non-null    int64
#  9   LSR_TIME_REST_RCRT_USE_RATE          530 non-null    int64
#  10  LSR_TIME_HOBBY_USE_RATE              530 non-null    int64
#  11  LSR_TIME_SELF_IMPT_USE_RATE          530 non-null    int64
#  12  LSR_TIME_TWDPSN_RLTN_FLWSP_USE_RATE  530 non-null    int64
#  13  LSR_TIME_ETC_USE_RATE                530 non-null    int64
# dtypes: int64(10), object(4)
# memory usage: 58.1+ KB

# %%
week1.describe()
# Out:
#          RESPOND_ID  EXAMIN_BEGIN_DE  WORKDAY_DAY_AVRG_LSR_TIME_VALUE  \
# count  5.300000e+02            530.0                       530.000000
# mean   5.334883e+07       20221005.0                         2.858491
# std    1.537525e+04              0.0                         2.036708
# min    5.332218e+07       20221005.0                         0.000000
# 25%    5.333603e+07       20221005.0                         1.000000
# 50%    5.334756e+07       20221005.0                         2.000000
# 75%    5.336163e+07       20221005.0                         4.000000
# max    5.337752e+07       20221005.0                        12.000000
#
#        WKEND_DAY_AVRG_LSR_TIME_VALUE  ONE_WEEK_TOT_LSR_TIME_VALUE  \
# count                     530.000000                   530.000000
# mean                        5.716981                    25.726415
# std                         3.356439                    14.587804
# min                         0.000000                     0.000000
# 25%                         3.000000                    15.000000
# 50%                         5.000000                    22.000000
# 75%                         8.000000                    35.000000
# max                        18.000000                    84.000000
#
#        LSR_TIME_REST_RCRT_USE_RATE  LSR_TIME_HOBBY_USE_RATE  \
# count                   530.000000               530.000000
# mean                     41.516981                18.271698
# std                      25.017209                18.334060
# min                       0.000000                 0.000000
# 25%                      20.000000                 0.000000
# 50%                      40.000000                10.000000
# 75%                      60.000000                30.000000
# max                     100.000000               100.000000
#
#        LSR_TIME_SELF_IMPT_USE_RATE  LSR_TIME_TWDPSN_RLTN_FLWSP_USE_RATE  \
# count                   530.000000                           530.000000
# mean                     13.986792                            23.073585
# std                      16.039230                            19.296323
# min                       0.000000                             0.000000
# 25%                       0.000000                            10.000000
# 50%                      10.000000                            20.000000
# 75%                      20.000000                            30.000000
# max                     100.000000                           100.000000
#
#        LSR_TIME_ETC_USE_RATE
# count             530.000000
# mean                3.150943
# std                10.022463
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                80.000000

# %%
week1
# Out:
#      RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0      53322175         20221005               F           20대
# 1      53322586         20221005               F           50대
# 2      53322613         20221005               F           50대
# 3      53322634         20221005               F           60대
# 4      53322657         20221005               M           60대
# ..          ...              ...             ...           ...
# 525    53376787         20221005               F           30대
# 526    53377297         20221005               F           40대
# 527    53377355         20221005               M           30대
# 528    53377490         20221005               M           30대
# 529    53377524         20221005               F           60대
#
#     ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  WORKDAY_DAY_AVRG_LSR_TIME_VALUE  \
# 0               서울특별시         300이상500만원 미만                                5
# 1               서울특별시         300이상500만원 미만                                3
# 2               서울특별시              700만원 이상                                3
# 3               서울특별시              300만원 미만                                2
# 4               서울특별시         300이상500만원 미만                               10
# ..                ...                   ...                              ...
# 525               경기도         500이상700만원 미만                                1
# 526             서울특별시         500이상700만원 미만                                2
# 527               경기도              300만원 미만                                1
# 528             대전광역시         300이상500만원 미만                                3
# 529               경기도         300이상500만원 미만                                3
#
#      WKEND_DAY_AVRG_LSR_TIME_VALUE  ONE_WEEK_TOT_LSR_TIME_VALUE  \
# 0                                8                           41
# 1                                2                           19
# 2                               12                           39
# 3                               10                           30
# 4                                4                           58
# ..                             ...                          ...
# 525                              6                           17
# 526                              5                           20
# 527                              1                            7
# 528                              3                           21
# 529                              3                           21
#
#      LSR_TIME_REST_RCRT_USE_RATE  LSR_TIME_HOBBY_USE_RATE  \
# 0                             20                       30
# 1                             60                       10
# 2                              0                       50
# 3                             50                       10
# 4                             10                       30
# ..                           ...                      ...
# 525                           40                       20
# 526                           50                        5
# 527                          100                        0
# 528                           50                       30
# 529                           10                       40
#
#      LSR_TIME_SELF_IMPT_USE_RATE  LSR_TIME_TWDPSN_RLTN_FLWSP_USE_RATE  \
# 0                             50                                    0
# 1                              5                                   15
# 2                              0                                   50
# 3                             10                                   10
# 4                             50                                   10
# ..                           ...                                  ...
# 525                           10                                   20
# 526                           10                                   35
# 527                            0                                    0
# 528                            0                                   20
# 529                           20                                   30
#
#      LSR_TIME_ETC_USE_RATE
# 0                        0
# 1                       10
# 2                        0
# 3                       20
# 4                        0
# ..                     ...
# 525                     10
# 526                      0
# 527                      0
# 528                      0
# 529                      0
#
# [530 rows x 14 columns]

# %%
week1['SEXDSTN_FLAG_CD'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
week1['AGRDE_FLAG_NM'].unique()
# Out:
# array(['20대', '50대', '60대', '40대', '30대'], dtype=object)

# %%
week1['ANSWRR_OC_AREA_NM'].unique()
# Out:
# array(['서울특별시', '경기도', '충청북도', '인천광역시', '대구광역시', '광주광역시', '전라북도', '전라남도',
#        '충청남도', '대전광역시', '강원도', '울산광역시', '경상남도', '세종특별자치시', '경상북도',
#        '부산광역시', '제주특별자치도'], dtype=object)

# %%
week1['HSHLD_INCOME_DGREE_NM'].unique()
# Out:
# array(['300이상500만원 미만', '700만원 이상', '300만원 미만', '500이상700만원 미만', '무응답'],
#       dtype=object)

# %%
df = pd.concat([week1, week2, week3, week4])

# %%
df
# Out:
#      RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0      53322175         20221005               F           20대
# 1      53322586         20221005               F           50대
# 2      53322613         20221005               F           50대
# 3      53322634         20221005               F           60대
# 4      53322657         20221005               M           60대
# ..          ...              ...             ...           ...
# 525    53377283         20221026               F           50대
# 526    53377318         20221026               M           50대
# 527    53377319         20221026               M           20대
# 528    53377395         20221026               M           50대
# 529    53377450         20221026               F           30대
#
#     ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  WORKDAY_DAY_AVRG_LSR_TIME_VALUE  \
# 0               서울특별시         300이상500만원 미만                                5
# 1               서울특별시         300이상500만원 미만                                3
# 2               서울특별시              700만원 이상                                3
# 3               서울특별시              300만원 미만                                2
# 4               서울특별시         300이상500만원 미만                               10
# ..                ...                   ...                              ...
# 525              충청북도              300만원 미만                                2
# 526               강원도         300이상500만원 미만                                1
# 527              전라북도              700만원 이상                                2
# 528             대구광역시              300만원 미만                                1
# 529               경기도              300만원 미만                                2
#
#      WKEND_DAY_AVRG_LSR_TIME_VALUE  ONE_WEEK_TOT_LSR_TIME_VALUE  \
# 0                                8                           41
# 1                                2                           19
# 2                               12                           39
# 3                               10                           30
# 4                                4                           58
# ..                             ...                          ...
# 525                              4                           18
# 526                              2                            9
# 527                              7                           24
# 528                              2                            9
# 529                             10                           30
#
#      LSR_TIME_REST_RCRT_USE_RATE  LSR_TIME_HOBBY_USE_RATE  \
# 0                             20                       30
# 1                             60                       10
# 2                              0                       50
# 3                             50                       10
# 4                             10                       30
# ..                           ...                      ...
# 525                           10                       80
# 526                           15                       35
# 527                           50                       20
# 528                           70                       30
# 529                           70                       10
#
#      LSR_TIME_SELF_IMPT_USE_RATE  LSR_TIME_TWDPSN_RLTN_FLWSP_USE_RATE  \
# 0                             50                                    0
# 1                              5                                   15
# 2                              0                                   50
# 3                             10                                   10
# 4                             50                                   10
# ..                           ...                                  ...
# 525                            0                                   10
# 526                           30                                   20
# 527                           20                                   10
# 528                            0                                    0
# 529                           15                                    5
#
#      LSR_TIME_ETC_USE_RATE
# 0                        0
# 1                       10
# 2                        0
# 3                       20
# 4                        0
# ..                     ...
# 525                      0
# 526                      0
# 527                      0
# 528                      0
# 529                      0
#
# [2122 rows x 14 columns]

# %%
df['SEXDSTN_FLAG_CD'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['AGRDE_FLAG_NM'].unique()
# Out:
# array(['20대', '50대', '60대', '40대', '30대'], dtype=object)

# %%
df['ANSWRR_OC_AREA_NM'].unique()
# Out:
# array(['서울특별시', '경기도', '충청북도', '인천광역시', '대구광역시', '광주광역시', '전라북도', '전라남도',
#        '충청남도', '대전광역시', '강원도', '울산광역시', '경상남도', '세종특별자치시', '경상북도',
#        '부산광역시', '제주특별자치도'], dtype=object)

# %%
df['HSHLD_INCOME_DGREE_NM'].unique()
# Out:
# array(['300이상500만원 미만', '700만원 이상', '300만원 미만', '500이상700만원 미만', '무응답'],
#       dtype=object)
